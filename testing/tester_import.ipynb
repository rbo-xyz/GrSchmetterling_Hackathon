# %%
import sys
from pathlib import Path

# einen Pfad relativ zum Notebook bauen
root = Path().resolve().parent  # wenn test.ipynb in testing_rbo/, geht parent auf Dein Projekt-Root
src  = root / "src"
sys.path.insert(0, str(src))

# jetzt kennt Python import_gpx.py
from import_gpx import import_gpx

# %%
# from import_gpx import import_gpx

# %%
filepath = "../data/7-gipfel-tour-flumserberg.gpx"

# %%
gdf = import_gpx(filepath)

# %%
gdf
# Out:
#    segment_id von_pkt_name                              von_pkt_geom  \
# 0           1   Startpunkt  POINT Z (2737832.731 1214786.689 1974.2)
#
#   bis_pkt_name                              bis_pkt_geom  \
# 0         Ziel  POINT Z (2739850.838 1217402.568 1379.8)
#
#                                         segment_geom
# 0  LINESTRING Z (2737832.731 1214786.689 1974.2, ...

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
filepath_v2 = "../data/map.geo.admin.ch_GPX_20250522075309.gpx"

# %%
gdf_v2 = import_gpx(filepath_v2)

# %%
gdf_v2
# Out:
#    segment_id     von_pkt_name                             von_pkt_geom  \
# 0           1       Startpunkt  POINT Z (2615292.286 1264887.924 279.7)
# 1           2     Hintere Burg  POINT Z (2616488.117 1263427.786 431.5)
# 2           3    Mittlere Burg   POINT Z (2616298.894 1263194.66 476.4)
# 3           4  Lecker Weinchen    POINT Z (2617072.551 1262557.063 411)
# 4           5      Schauenburg  POINT Z (2618037.624 1261126.735 568.2)
#
#       bis_pkt_name                             bis_pkt_geom  \
# 0     Hintere Burg  POINT Z (2616488.117 1263427.786 431.5)
# 1    Mittlere Burg   POINT Z (2616298.894 1263194.66 476.4)
# 2  Lecker Weinchen    POINT Z (2617072.551 1262557.063 411)
# 3      Schauenburg  POINT Z (2618037.624 1261126.735 568.2)
# 4             Ende  POINT Z (2621085.137 1261293.638 310.5)
#
#                                         segment_geom
# 0  LINESTRING Z (2615292.286 1264887.924 279.7, 2...
# 1  LINESTRING Z (2616488.117 1263427.786 431.5, 2...
# 2  LINESTRING Z (2616298.894 1263194.66 476.4, 26...
# 3  LINESTRING Z (2617072.551 1262557.063 411, 261...
# 4  LINESTRING Z (2618037.624 1261126.735 568.2, 2...

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   segment_id    1 non-null      int16
#  1   von_pkt_name  1 non-null      object
#  2   von_pkt_geom  1 non-null      geometry
#  3   bis_pkt_name  1 non-null      object
#  4   bis_pkt_geom  1 non-null      geometry
#  5   segment_geom  1 non-null      geometry
# dtypes: geometry(3), int16(1), object(2)
# memory usage: 174.0+ bytes

# %%
gdf_v2.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   segment_id    5 non-null      int16
#  1   von_pkt_name  5 non-null      object
#  2   von_pkt_geom  5 non-null      geometry
#  3   bis_pkt_name  5 non-null      object
#  4   bis_pkt_geom  5 non-null      geometry
#  5   segment_geom  5 non-null      geometry
# dtypes: geometry(3), int16(1), object(2)
# memory usage: 342.0+ bytes

# %%
gdf_v2.plot()
# Out:
# <Axes: >

# %%
path = "../data/second_Testdata_Arosa.gpx"

# %%
gdf_v3 = import_gpx(path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gdf_v3 = import_gpx(path)
#
# File ~\Documents\01_lokal_Ablage_FHNW_temp\4040_GP2\30_Hackathon\GrSchmeterling_Hackathon\src\import_gpx.py:38, in import_gpx(filepath)
#      36     gdf = import_app(filepath)
#      37 if source == "web":
# ---> 38     gdf = import_web(filepath)
#      39 if source == "unknown":
#      40     raise ValueError(f"Datei '{filepath}' ist weder von der Swisstopo-App noch vom Siwsstopo-GIS erstellt worden.")
#
# File ~\Documents\01_lokal_Ablage_FHNW_temp\4040_GP2\30_Hackathon\GrSchmeterling_Hackathon\src\import_gpx.py:168, in import_web(filepath)
#     158 ## Diese Codestelle kann verwendet werden, wenn jeder Punkt eine Polyline bei der API abgefragt werden soll.
#     159 ## --> Nächster Abschnitt auskommentieren
#     160 # ## Erstellung 3D-LineStrings
#    (...)    165 ## --> letzter Abschnitt auskommentieren
#     166 ## Erstellung 3D-LineStrings via Profile-API (nur 1 Request pro Segment)
#     167 gdf_lines_3d = gdf_lines.copy()
# --> 168 gdf_lines_3d["geometry"] = gdf_lines.geometry.apply(lambda ln: to_3d_linestring_profile(ln))
#     170 ## CRS neu setzen
#     171 gdf_waypoints = gdf_waypoints.set_crs(epsg=2056, allow_override=True)
#
# File c:\Users\r.boppart\anaconda3\envs\4040Hackathon_py313\Lib\site-packages\geopandas\geoseries.py:752, in GeoSeries.apply(self, func, convert_dtype, args, **kwargs)
#     749         kwargs["convert_dtype"] = True
#     751 # to avoid warning
# --> 752 result = super().apply(func, args=args, **kwargs)
#     753 if isinstance(result, GeoSeries):
#     754     if self.crs is not None:
#
# File c:\Users\r.boppart\anaconda3\envs\4040Hackathon_py313\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\r.boppart\anaconda3\envs\4040Hackathon_py313\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\r.boppart\anaconda3\envs\4040Hackathon_py313\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\r.boppart\anaconda3\envs\4040Hackathon_py313\Lib\site-packages\pandas\core\base.py:919, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     916 arr = self._values
#     918 if isinstance(arr, ExtensionArray):
# --> 919     return arr.map(mapper, na_action=na_action)
#     921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\r.boppart\anaconda3\envs\4040Hackathon_py313\Lib\site-packages\pandas\core\arrays\base.py:2322, in ExtensionArray.map(self, mapper, na_action)
#    2302 def map(self, mapper, na_action=None):
#    2303     """
#    2304     Map values using an input mapping or function.
#    2305
#    (...)   2320         a MultiIndex will be returned.
#    2321     """
# -> 2322     return map_array(self, mapper, na_action=na_action)
#
# File c:\Users\r.boppart\anaconda3\envs\4040Hackathon_py313\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~\Documents\01_lokal_Ablage_FHNW_temp\4040_GP2\30_Hackathon\GrSchmeterling_Hackathon\src\import_gpx.py:168, in import_web.<locals>.<lambda>(ln)
#     158 ## Diese Codestelle kann verwendet werden, wenn jeder Punkt eine Polyline bei der API abgefragt werden soll.
#     159 ## --> Nächster Abschnitt auskommentieren
#     160 # ## Erstellung 3D-LineStrings
#    (...)    165 ## --> letzter Abschnitt auskommentieren
#     166 ## Erstellung 3D-LineStrings via Profile-API (nur 1 Request pro Segment)
#     167 gdf_lines_3d = gdf_lines.copy()
# --> 168 gdf_lines_3d["geometry"] = gdf_lines.geometry.apply(lambda ln: to_3d_linestring_profile(ln))
#     170 ## CRS neu setzen
#     171 gdf_waypoints = gdf_waypoints.set_crs(epsg=2056, allow_override=True)
#
# File ~\Documents\01_lokal_Ablage_FHNW_temp\4040_GP2\30_Hackathon\GrSchmeterling_Hackathon\src\import_gpx.py:345, in to_3d_linestring_profile(line2d, crs, nb_points, offset, distinct_points, which)
#     342     params["offset"] = str(offset)
#     344 r = requests.get(url, params=params, timeout=10)
# --> 345 r.raise_for_status()
#     347 profile = r.json()
#     349 coords3d = [
#     350     (pt["easting"], pt["northing"], pt["alts"][which])
#     351     for pt in profile
#     352 ]
#
# File c:\Users\r.boppart\anaconda3\envs\4040Hackathon_py313\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api3.geo.admin.ch/rest/services/profile.json?geom=%7B%22type%22%3A+%22LineString%22%2C+%22coordinates%22%3A+%5B%5B2773796.3515946334%2C+1182123.0882057052%5D%2C+%5B2773807.195880802%2C+1182128.2494628062%5D%2C+%5B2773826.6845268235%2C+1182121.4662200408%5D%2C+%5B2773877.7363060573%2C+1182151.5668597515%5D%2C+%5B2773876.582224074%2C+1182159.5739049802%5D%2C+%5B2773874.5588094164%2C+1182173.6123987022%5D%2C+%5B2773868.415649252%2C+1182193.538174298%5D%2C+%5B2773855.2072751652%2C+1182257.1464530323%5D%2C+%5B2773854.8583302596%2C+1182258.8268858162%5D%2C+%5B2773806.984047636%2C+1182295.922744649%5D%2C+%5B2773786.494340774%2C+1182327.5916105388%5D%2C+%5B2773785.588903626%2C+1182328.9910530888%5D%2C+%5B2773728.605797329%2C+1182337.4701065521%5D%2C+%5B2773746.3997784695%2C+1182357.6078584741%5D%2C+%5B2773734.758383337%2C+1182365.1107757296%5D%2C+%5B2773733.901625042%2C+1182365.662959254%5D%2C+%5B2773732.630626382%2C+1182386.6486165216%5D%2C+%5B2773743.222281824%2C+1182395.1276699654%5D%2C+%5B2773725.4283006685%2C+1182417